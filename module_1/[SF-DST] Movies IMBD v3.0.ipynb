# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("../input"))

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
answer_ls.append(4)

# %%
data[['original_title', 'budget']].sort_values(by='budget', ascending=False).head()
# Out:
#                                    original_title     budget
# 491                             The Warrior's Way  425000000
# 724   Pirates of the Caribbean: On Stranger Tides  380000000
# 1670     Pirates of the Caribbean: At World's End  300000000
# 14                        Avengers: Age of Ultron  280000000
# 1015                                  John Carter  260000000

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
answer_ls.append(2)

# %%
data[['original_title', 'runtime']].sort_values(by='runtime', ascending=False).head()
# Out:
#                                      original_title  runtime
# 1158                              Gods and Generals      214
# 1082  The Lord of the Rings: The Return of the King      201
# 1737                                     Grindhouse      191
# 1337                                      King Kong      187
# 505                                    Pearl Harbor      183

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
answer_ls.append(3)

# %%
data[['original_title', 'runtime']].sort_values(by='runtime').head()
# Out:
#             original_title  runtime
# 769        Winnie the Pooh       63
# 931   Return to Never Land       72
# 1098     The Jungle Book 2       72
# 1627     Home on the Range       76
# 1409               Valiant       76

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
answer_ls.append(2)

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
answer_ls.append(1)

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
answer_ls.append(5)

# %%
data['profit'] = data['revenue'] - data['budget']
data[['profit', 'original_title', 'imdb_id', 'revenue', 'budget']].sort_values('profit', ascending=False).head()
# Out:
#          profit                original_title    imdb_id     revenue  \
# 239  2544505847                        Avatar  tt0499549  2781505847
# 3    1868178225  Star Wars: The Force Awakens  tt2488496  2068178225
# 0    1363528810                Jurassic World  tt0369610  1513528810
# 4    1316249360                     Furious 7  tt2820852  1506249360
# 971  1299557910                  The Avengers  tt0848228  1519557910
#
#         budget
# 239  237000000
# 3    200000000
# 0    150000000
# 4    190000000
# 971  220000000

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
answer_ls.append(2)

# %%
data['profit'] = data['revenue'] - data['budget']
data[['profit', 'original_title', 'imdb_id', 'revenue', 'budget']].sort_values('profit').head()
# Out:
#          profit                original_title    imdb_id   revenue     budget
# 491  -413912431             The Warrior's Way  tt1032751  11087569  425000000
# 1246 -165710090               The Lone Ranger  tt1210819  89289910  255000000
# 1617 -119180039                     The Alamo  tt0318974  25819961  145000000
# 810  -111007242               Mars Needs Moms  tt1305591  38992758  150000000
# 959   -92896027  The Adventures of Pluto Nash  tt0180052   7103973  100000000

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
answer_ls.append(1)

# %%
data['profit'] = data['revenue'] - data['budget']
data[data.profit > 0].original_title.value_counts().sum()
# Out:
# 1478

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
answer_ls.append(4)

# %%
data['profit'] = data['revenue'] - data['budget']
data[['profit', 'original_title', 'imdb_id', 'revenue', 'budget', 'release_year']][(data.release_year == 2008)].sort_values(by='profit', ascending=False).head()
# Out:
#         profit                                     original_title    imdb_id  \
# 600  816921825                                    The Dark Knight  tt0468569
# 604  601636033  Indiana Jones and the Kingdom of the Crystal S...  tt0367882
# 608  557841637                                         Mamma Mia!  tt0795421
# 607  501744560                                      Kung Fu Panda  tt0441773
# 622  474029371                                            Hancock  tt0448157
#
#         revenue     budget  release_year
# 600  1001921825  185000000          2008
# 604   786636033  185000000          2008
# 608   609841637   52000000          2008
# 607   631744560  130000000          2008
# 622   624029371  150000000          2008

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
answer_ls.append(5)

# %%
data['profit'] = data['revenue'] - data['budget']
data[['profit', 'original_title', 'imdb_id', 'revenue', 'budget', 'release_year']][(data.release_year >= 2012)&(data.release_year <= 2014)].sort_values(by='profit').head()
# Out:
#          profit                   original_title    imdb_id   revenue  \
# 1246 -165710090                  The Lone Ranger  tt1210819  89289910
# 1215  -68351500                         R.I.P.D.  tt0790736  61648500
# 1008  -51893525                      Upside Down  tt1374992   8106475
# 1303  -51337973  Legends of Oz: Dorothy's Return  tt0884726  18662027
# 1236  -45510171               Bullet to the Head  tt1308729   9489829
#
#          budget  release_year
# 1246  255000000          2013
# 1215  130000000          2013
# 1008   60000000          2012
# 1303   70000000          2013
# 1236   55000000          2013

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
answer_ls.append(3)

# %%
genre_counter = Counter()
for x in data.genres.str.split('|'):
    genre_counter += Counter(x)
genre_counter.most_common()
# Out:
# [('Drama', 782),
#  ('Comedy', 683),
#  ('Thriller', 597),
#  ('Action', 583),
#  ('Adventure', 416),
#  ('Crime', 315),
#  ('Romance', 308),
#  ('Family', 260),
#  ('Science Fiction', 248),
#  ('Fantasy', 223),
#  ('Horror', 176),
#  ('Mystery', 168),
#  ('Animation', 139),
#  ('Music', 64),
#  ('History', 62),
#  ('War', 58),
#  ('Western', 20),
#  ('Documentary', 8),
#  ('Foreign', 2)]

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
answer_ls.append(1)

# %%
genres = set()
for x in data.genres.apply(lambda x: x.split('|')):
    genres |= set(x)
best_genres=[( len(data[(data.genres.str.contains(x)) & (data.profit > 0)]) , x) for x in genres]
best_genres.sort(reverse=True)
best_genres
# Out:
# [(560, 'Drama'),
#  (551, 'Comedy'),
#  (446, 'Thriller'),
#  (444, 'Action'),
#  (337, 'Adventure'),
#  (242, 'Romance'),
#  (231, 'Crime'),
#  (226, 'Family'),
#  (195, 'Science Fiction'),
#  (188, 'Fantasy'),
#  (150, 'Horror'),
#  (120, 'Animation'),
#  (119, 'Mystery'),
#  (47, 'Music'),
#  (46, 'History'),
#  (41, 'War'),
#  (12, 'Western'),
#  (7, 'Documentary'),
#  (0, 'Foreign')]

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
answer_ls.append(3)

# %%
data['director'].value_counts()
# Out:
# Steven Soderbergh    13
# Ridley Scott         12
# Clint Eastwood       12
# Shawn Levy           10
# Steven Spielberg     10
#                      ..
# David Barrett         1
# Stephen Hopkins       1
# Theodore Melfi        1
# Bryan Bertino         1
# Daniel Sackheim       1
# Name: director, Length: 958, dtype: int64

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
answer_ls.append(4)

# %%
data[data.profit > 0].groupby(['director']).agg('count')['imdb_id'].sort_values(ascending=False).head()
# Out:
# director
# Ridley Scott         12
# Steven Spielberg     10
# Steven Soderbergh    10
# Clint Eastwood       10
# Shawn Levy            9
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
answer_ls.append(5)

# %%
c = Counter()
for index, row in data.iterrows():
    names = row.director.split(sep='|')
    for name in names:
        c[name] += row.profit   
display(c.most_common(5))
# Out:
# [('Peter Jackson', 5202593685),
#  ('David Yates', 3379295625),
#  ('Christopher Nolan', 3162548502),
#  ('J.J. Abrams', 2839169916),
#  ('Michael Bay', 2760938960)]

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
answer_ls.append(1)

# %%
c = Counter()
for index, row in data.iterrows():
    names = row.cast.split(sep='|')
    for name in names:
        c[name] += row.profit   
display(c.most_common(5))
# Out:
# [('Emma Watson', 6666245597),
#  ('Daniel Radcliffe', 6514990281),
#  ('Rupert Grint', 6408638290),
#  ('Ian McKellen', 6087375777),
#  ('Robert Downey Jr.', 5316030161)]

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
answer_ls.append(3)

# %%
actors = set()
for x in data.cast.apply(lambda x: x.split('|')):
    actors |= set(x)
worst_actors=[ (data[(data.release_year == 2012) & (data.cast.str.contains(x))]['profit'].sum(), x) for x in actors]
worst_actors.sort()
worst_actors
# Out:
# [(-68109207, 'Kirsten Dunst'),
#  (-51893525, 'Heidi Hawkins'),
#  (-51893525, 'James Kidnie'),
#  (-51893525, 'Timothy Spall'),
#  (-43733509, 'Malin Ã…kerman'),
#  (-32893443, 'Danny Huston'),
#  (-32893443, 'Josh Lucas'),
#  (-32893443, 'Nicolas Cage'),
#  (-32893443, 'Sami Gayle'),
#  (-23410657, 'Jim Sturgess'),
#  (-22141997, 'John Krasinski'),
#  (-20193217, 'Adrianne Palicki'),
#  (-20193217, 'Isabel Lucas'),
#  (-17955723, 'Allison Janney'),
#  (-17955723, 'Clark Duke'),
#  (-17955723, 'Cliff Curtis'),
#  (-17955723, 'Eddie Murphy'),
#  (-16215682, 'Garrett Hedlund'),
#  (-16215682, 'Sam Riley'),
#  (-16215682, 'Tom Sturridge'),
#  (-15581387, 'Diego Boneta'),
#  (-15581387, 'Julianne Hough'),
#  (-15363831, '50 Cent'),
#  (-15363831, 'Josh Duhamel'),
#  (-15363831, 'Rosario Dawson'),
#  (-15363831, "Vincent D'Onofrio"),
#  (-15280785, 'Dermot Mulroney'),
#  (-15280785, 'Drew Barrymore'),
#  (-15280785, 'Kristen Bell'),
#  (-15280785, 'Vinessa Shaw'),
# ...

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
answer_ls.append(3)

# %%
best_actor = data[data['budget']>data['budget'].mean()]
pd.DataFrame(best_actor.cast.str.split('|').tolist()).stack().value_counts()
# Out:
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Samuel L. Jackson    15
# Tom Cruise           15
#                      ..
# Rhona Mitra           1
# Vera Farmiga          1
# Kelly Macdonald       1
# Leonard Nimoy         1
# GÃ©rard Depardieu     1
# Length: 1508, dtype: int64

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
answer_ls.append(2)

# %%
cage_genres=[ ( len(data[(data.genres.str.contains(x)) & (data.cast.str.contains('Nicolas Cage'))]) , x) for x in genres]
cage_genres.sort(reverse=True)
cage_genres
# Out:
# [(17, 'Action'),
#  (15, 'Thriller'),
#  (12, 'Drama'),
#  (10, 'Crime'),
#  (8, 'Fantasy'),
#  (7, 'Adventure'),
#  (6, 'Comedy'),
#  (4, 'Science Fiction'),
#  (3, 'Mystery'),
#  (3, 'Family'),
#  (3, 'Animation'),
#  (2, 'History'),
#  (1, 'War'),
#  (1, 'Romance'),
#  (1, 'Horror'),
#  (0, 'Western'),
#  (0, 'Music'),
#  (0, 'Foreign'),
#  (0, 'Documentary')]

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
answer_ls.append(1)

# %%
c = Counter()
for index, row in data.iterrows():
    names = row.production_companies.split(sep='|')
    for name in names:
        c[name] += 1   
display(c.most_common(5))
# Out:
# [('Universal Pictures', 173),
#  ('Warner Bros.', 168),
#  ('Paramount Pictures', 122),
#  ('Columbia Pictures', 117),
#  ('Twentieth Century Fox Film Corporation', 109)]

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
answer_ls.append(4)

# %%
studios=pd.DataFrame(movie_studios, columns=['imdb_id', 'studio'])   
data[['imdb_id']][data.release_year == 2015].merge(studios, on='imdb_id').groupby('studio').agg('count').sort_values(by='imdb_id', ascending=False).head()
# Out:
#                                         imdb_id
# studio
# Warner Bros.                                 12
# Universal Pictures                           10
# Twentieth Century Fox Film Corporation        8
# Columbia Pictures                             7
# Paramount Pictures                            7

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
answer_ls.append(2)

# %%
data[['imdb_id', 'profit']][data.genres.str.contains('Comedy')].merge(studios, on='imdb_id').groupby('studio').agg('sum').sort_values(by='profit', ascending=False).head()
# Out:
#                                             profit
# studio
# Universal Pictures                      8961545581
# Walt Disney Pictures                    7669710326
# Twentieth Century Fox Film Corporation  5686960294
# Columbia Pictures                       5646343696
# DreamWorks Animation                    4789049764

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
answer_ls.append(3)

# %%
data[['imdb_id', 'profit']][data.release_year == 2012].merge(studios, on = 'imdb_id').groupby('studio').agg('sum').sort_values( by = 'profit', ascending=False).head()
# Out:
#                         profit
# studio
# Columbia Pictures   2501406608
# Universal Pictures  1981011579
# Marvel Studios      1299557910
# Warner Bros.        1258020056
# Relativity Media    1032593938

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
answer_ls.append(1)

# %%
stud_id=[]
for index, i in data.iterrows():
    stud_id +=  [ (i.imdb_id, x) for x in i.production_companies.split('|')]
set([ x[1] for x in stud_id if x[1].find('Paramount') != -1])
data[['profit', 'original_title']][data.production_companies.str.contains('Paramount Pictures')].sort_values(by='profit', ascending=True).head()
# Out:
#         profit        original_title
# 926  -64831034  K-19: The Widowmaker
# 1124 -60519261              Timeline
# 1723 -51788987                  Next
# 1624 -46604061                 Alfie
# 1632 -24805000               Twisted

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
answer_ls.append(5)

# %%
data.groupby(by = 'release_year')['revenue'].sum()
# Out:
# release_year
# 2000    10664099805
# 2001    13017764865
# 2002    14136361487
# 2003    14346123312
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2007    18162406801
# 2008    18252781990
# 2009    20261791024
# 2010    21082292530
# 2011    22676791872
# 2012    23079001687
# 2013    23213799791
# 2014    23405862953
# 2015    25449202382
# Name: revenue, dtype: int64

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
answer_ls.append(1)

# %%
warner_df = data.loc[data['production_companies'].apply(lambda x: 'Warner Bros.' in x)]
grouped_df = warner_df.groupby(['release_year'])['revenue'].sum()
grouped_df.sort_values()
# Out:
# release_year
# 2000    1025531386
# 2006    1521170743
# 2015    1691168351
# 2002    1702709901
# 2012    1869520056
# 2001    2266545668
# 2005    2412980298
# 2013    2599953400
# 2004    2731933725
# 2009    2737954136
# 2003    2745493377
# 2011    2845393682
# 2010    3008712985
# 2008    3050595031
# 2007    3183675217
# 2014    3243064519
# Name: revenue, dtype: int64

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
answer_ls.append(4)

# %%
data['release_month'] = pd.to_datetime(data.release_date).apply(lambda x: x.month)
data.groupby('release_month').agg('count').sort_values('imdb_id', ascending = False).head()
# Out:
#                imdb_id  popularity  budget  revenue  original_title  cast  \
# release_month
# 9                  227         227     227      227             227   227
# 12                 191         191     191      191             191   191
# 10                 186         186     186      186             186   186
# 8                  161         161     161      161             161   161
# 3                  156         156     156      156             156   156
#
#                director  tagline  overview  runtime  genres  \
# release_month
# 9                   227      227       227      227     227
# 12                  191      191       191      191     191
# 10                  186      186       186      186     186
# 8                   161      161       161      161     161
# 3                   156      156       156      156     156
#
#                production_companies  release_date  vote_count  vote_average  \
# release_month
# ...

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
answer_ls.append(2)

# %%
len(data[data.release_month.isin([6, 7, 8])])
# Out:
# 450

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
answer_ls.append(5)

# %%
data[['imdb_id', 'director']][data.release_month.isin([1, 2, 12])].groupby('director').agg('count').sort_values('imdb_id', ascending=False).head()
# Out:
#                    imdb_id
# director
# Peter Jackson            7
# Steven Soderbergh        6
# Clint Eastwood           6
# Adam Shankman            4
# Nancy Meyers             4

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
answer_ls.append(2)

# %%
detal_data = data.groupby(['release_year', 'release_month']).agg('sum')
year_max = detal_data.groupby('release_year').agg('max')[['profit']].rename(columns ={"profit": "max_profit"})
detal_data.reset_index(inplace = True)
detal_data = detal_data.merge(year_max, on = 'release_year')
detal_data[detal_data.profit == detal_data.max_profit].release_month.value_counts().sort_values(ascending = False)
# Out:
# 6     7
# 5     4
# 12    4
# 7     1
# Name: release_month, dtype: int64

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
answer_ls.append(5)

# %%
data['symbols'] = data.original_title.apply(len)
studios.merge(data, on = 'imdb_id').groupby('studio').agg('mean').sort_values('symbols', ascending = False).head()
# Out:
#                            popularity       budget      revenue  runtime  \
# studio
# Four By Two Productions      1.930735   18000000.0  261572744.0     82.0
# Jim Henson Company, The      0.876514   28000000.0  100654149.0     81.0
# Dos Corazones                0.628612   12000000.0    9622846.0    145.0
# Polsky Films                 0.643829   25000000.0   10589102.0    122.0
# Museum Canada Productions    1.752134  150000000.0  413106170.0    105.0
#
#                            vote_count  vote_average  release_year  \
# studio
# Four By Two Productions         979.0           6.4        2006.0
# Jim Henson Company, The         380.0           6.2        2014.0
# Dos Corazones                    20.0           6.8        2012.0
# Polsky Films                    157.0           5.8        2009.0
# Museum Canada Productions      1108.0           5.9        2009.0
#
#                                 profit  release_month  nlen  symbols
# studio
# ...

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
answer_ls.append(5)

# %%
data['words'] = data.original_title.apply(lambda x: len(x.split()))
studios.merge(data, on = 'imdb_id').groupby('studio').agg('mean').sort_values('words', ascending = False).head()
# Out:
#                          popularity      budget      revenue  runtime  \
# studio
# Four By Two Productions    1.930735  18000000.0  261572744.0     82.0
# Jim Henson Company, The    0.876514  28000000.0  100654149.0     81.0
# Dos Corazones              0.628612  12000000.0    9622846.0    145.0
# Polsky Films               0.643829  25000000.0   10589102.0    122.0
# The Saul Zaentz Company    8.335347  86000000.0  898827882.0    178.5
#
#                          vote_count  vote_average  release_year       profit  \
# studio
# Four By Two Productions       979.0           6.4        2006.0  243572744.0
# Jim Henson Company, The       380.0           6.2        2014.0   72654149.0
# Dos Corazones                  20.0           6.8        2012.0   -2377154.0
# Polsky Films                  157.0           5.8        2009.0  -14410898.0
# The Saul Zaentz Company      5596.5           7.8        2001.5  812827882.0
#
#                          release_month  nlen  symbols  words
# ...

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
answer_ls.append(3)

# %%
words = set()
for i in data['original_title'].to_list():
    for j in i.lower().split():
        words.add(j)
print(len(words))
# Out:
# 2461

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
answer_ls.append(1)

# %%
data.sort_values(by = 'vote_average', ascending = False).head(int(len(data)*0.01)+1)[['original_title', 'vote_average']]
# Out:
#                                          original_title  vote_average
# 600                                     The Dark Knight           8.1
# 125                                  The Imitation Game           8.0
# 9                                            Inside Out           8.0
# 118                                        Interstellar           8.0
# 34                                                 Room           8.0
# 1082      The Lord of the Rings: The Return of the King           7.9
# 873                                         The Pianist           7.9
# 1801                                            Memento           7.9
# 1192                                   12 Years a Slave           7.9
# 128                                           Gone Girl           7.9
# 138                            The Grand Budapest Hotel           7.9
# 119                             Guardians of the Galaxy           7.9
# ...

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
answer_ls.append(5)

# %%
import itertools
import collections

artists = collections.Counter()
for i, j in data.iterrows():
    b = j.cast.split('|')
    artists.update([ x for x in itertools.combinations(b, 2)])
artists.most_common(5)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8),
#  (('Daniel Radcliffe', 'Emma Watson'), 8),
#  (('Rupert Grint', 'Emma Watson'), 7),
#  (('Ben Stiller', 'Owen Wilson'), 6),
#  (('Johnny Depp', 'Helena Bonham Carter'), 6)]

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
answer_ls.append(1)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 72

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       1
# 2    3       4
# 3    4       2
# 4    5       3
# ..  ..     ...
# 67  68       5
# 68  69       3
# 69  70       1
# 70  71       5
# 71  72       1
#
# [72 rows x 2 columns]
